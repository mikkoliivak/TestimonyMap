# %%
import json

# %%
datacenter_data = [
	{
		"name": "Greenidge",
		"lat": 42.679497185829845,
		"lng": -76.94756944867795,
		"county": "Yates",
		"testimonies": [
			{
				"statement": "Those nearby began to hear a low droning noise, described by one resident as the sound of a jet that never lands.",
				"date": "9-27-2023",
				"source": "https://earthjustice.org/article/cleaning-up-crypto",
				"source-details": "Earthjustice"
			},
			{
				"statement": "The organization Earthjustice states that the volume of the machinery in crypto mining facilities can reach 95 decibels, about the same as a moving subway train.",
				"date": "5-3-2025",
				"source": "https://ithacaweek-ic.com/17097/news/uncertainty-plagues-greenidge-crypto-mine/",
				"source-details": "Ithaca Week"
			},
			{
				"statement": "Residents living near mining facilities have reported problems like blood pressure spikes, tinnitus, migraines, permanent hearing loss; and even problems with pets, like hair loss and the development of chronic anxiety in dogs.",
				"date": "5-3-2025",
				"source": "https://ithacaweek-ic.com/17097/news/uncertainty-plagues-greenidge-crypto-mine/",
				"source-details": "Ithaca Week"
			},
			{
				"statement": "The lake is so warm you feel like you're in a hot tub.",
				"date": "7-7-2021",
				"source": "https://www.nbcnews.com/science/environment/some-locals-say-bitcoin-mining-operation-ruining-one-finger-lakes-n1272938",
				"source-details": "NBC News"
			},
			{
				"statement": "A lot of people get their water directly from the lake, and if there is a harmful outbreak, you don't want to bathe or cook or even flush your toilets with it.",
				"date": "2021",
				"source": "https://www.ewg.org/research/proof-problems-bitcoin-minings-pollution-toll-us-communities/new-york",
				"source-details": "Environmental Working Group"
			},
			{
				"statement": "It's like a giant fish blender.",
				"date": "2021",
				"source": "https://www.ewg.org/research/proof-problems-bitcoin-minings-pollution-toll-us-communities/new-york",
				"source-details": "Environmental Working Group"
			},
			{
				"statement": "The company reaps the rewards, not the community.",
				"date": "2025",
				"source": "https://www.thecooldown.com/green-business/crypto-mining-new-york-greenidge-generation/",
				"source-details": "The Cool Down"
			},
			{
				"statement": "It's being done for pure greed at the expense of all the rest of us.",
				"date": "5-3-2025",
				"source": "https://ithacaweek-ic.com/17097/news/uncertainty-plagues-greenidge-crypto-mine/",
				"source-details": "Ithaca Week"
			},
			{
				"statement": "Greenidge is continuing to find loopholes and appealing that decision, and while it's doing all of that, it's allowed to continue operating. While it's continuing to operate, it is continuing to undermine our climate and to cause health issues and concerns for our community.",
				"date": "5-3-2025",
				"source": "https://ithacaweek-ic.com/17097/news/uncertainty-plagues-greenidge-crypto-mine/",
				"source-details": "Ithaca Week"
			},
			{
				"statement": "The Finger Lake communities surrounding the Greenidge Generation cryptomining operation have had enough of the corporation's nonstop abuse. Impacted community members have been sounding the alarm on the disastrous impacts of the Greenidge cryptomine on their water, air, and climate.",
				"date": "12-20-2024",
				"source": "https://earthjustice.org/press/2024/cryptominer-greenidge-tries-to-gift-finger-lakes-community-with-years-of-more-litigation",
				"source-details": "Earthjustice"
			}
		]
	},
	{
		"name": "Lake Mariner",
		"lat": 43.347683,
		"lng": -78.555656,
		"county": "Niagara",
		"testimonies": [
			{
				"statement": "They told us the noise wouldn't be a problem. It's a problem. The constant hum keeps us up at night. And now they're expanding again.",
				"date": "10-9-2025",
				"source": "https://www.fingerlakes1.com/2025/10/09/lansing-residents-call-for-answers-as-terawulf-data-center-plans-unravel/",
				"source-details": "FingerLakes1"
			},
			{
				"statement": "The sound is different all the time. Last Tuesday morning it was extremely loud, especially at 5 a.m. in the morning … Sometimes we don't hear it at all and sometimes it's excessively loud.",
				"date": "11-14-2024",
				"source": "https://tech.yahoo.com/ai/articles/ai-data-center-plan-approved-045900997.html",
				"source-details": "Yahoo Tech"
			},
			{
				"statement": "I've lived in my house for 35 years. So I was there when the power plant was running at full bore and it was at night, not as bothersome as it is now. I think part of the problem is it's steady now. It's not peak and valley noise.",
				"date": "10-9-2024",
				"source": "https://www.yahoo.com/tech/somerset-data-center-pitches-buildings-035900867.html",
				"source-details": "Yahoo Tech"
			}
		]
	},
	{
		"name": "H5 Datacenters",
		"lat": 43.167553,
		"lng": -78.751731,
		"county": "Niagara",
		"testimonies": [
			
		]
	}
]
